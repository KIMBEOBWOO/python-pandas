# %% [markdown]
# ### (1-1) 선 그래프

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font', family='AppleGothic')    # 맥 한글 폰트 꺠짐 처리하기

df = pd.read_excel('../../data/part4/시도별 전출입 인구수.xlsx', header=0)

df = df.fillna(method='ffill')

mask = (df['전출지별'] == '서울특별시') & (df['전입지별'] != '서울특별시')          # 서울에서 서울이 아닌 다른 곳으로 이동한 데이터 추출
df_seoul = df[mask]                                                   
df_seoul = df_seoul.drop(['전출지별'], axis=1)                              # 전출지는 서울 이므로 삭제
df_seoul.rename({'전입지별':'전입지'}, axis=1, inplace=True)              # 전입지별 -> 전입지 로 변경
df_seoul.set_index('전입지', inplace=True)                                  # 전입지 열을 행 이름 인덱스로 변경

df_seoul.head()
# Out:
#           1970     1971     1972     1973     1974     1975     1976     1977  \
# 전입지
# 전국     1448985  1419016  1210559  1647268  1819660  2937093  2495620  2678007
# 부산광역시    11568    11130    11768    16307    22220    27515    23732    27213
# 대구광역시        -        -        -        -        -        -        -        -
# 인천광역시        -        -        -        -        -        -        -        -
# 광주광역시        -        -        -        -        -        -        -        -
#
#           1978     1979  ...     2008     2009     2010     2011     2012  \
# 전입지                      ...
# 전국     3028911  2441242  ...  2083352  1925452  1848038  1834806  1658928
# 부산광역시    29856    28542  ...    17353    17738    17418    18816    16135
# 대구광역시        -        -  ...     9720    10464    10277    10397    10135
# 인천광역시        -        -  ...    50493    45392    46082    51641    49640
# 광주광역시        -        -  ...    10846    11725    11095    10587    10154
#
# ...

# %%
# 서울에서 경기도로 이동한 데이터만 선택
sr_one = df_seoul.loc['경기도']

# 선 그래프
plt.plot(sr_one.index, sr_one.values)   # 선택한 시리즈의 index 를 x 축으로, value 를 y 축으로 전달

# 차트 제목 추가
plt.title('서울 -> 경기도')

# 축 이름 추가
plt.xlabel('기간')
plt.ylabel('이동 인구수')

# 변경사항 저장 후 그래프 출력
plt.show()

# %% [markdown]
# 현재 위의 그래프는 x 축 값이 겹쳐져서 제대로 확인이 안된다.
# 따라서,
# 1. 그림틀의 가로 사이즈 크기 변경
# 2. 축의 이름 90도 회전

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font', family='AppleGothic')    # 맥 한글 폰트 꺠짐 처리하기

df = pd.read_excel('../../data/part4/시도별 전출입 인구수.xlsx', header=0)

df = df.fillna(method='ffill')
mask = (df['전출지별'] == '서울특별시') & (df['전입지별'] != '서울특별시')          # 서울에서 서울이 아닌 다른 곳으로 이동한 데이터 추출
df_seoul = df[mask]                                                   
df_seoul = df_seoul.drop(['전출지별'], axis=1)                              # 전출지는 서울 이므로 삭제
df_seoul.rename({'전입지별':'전입지'}, axis=1, inplace=True)              # 전입지별 -> 전입지 로 변경
df_seoul.set_index('전입지', inplace=True)                                  # 전입지 열을 행 이름 인덱스로 변경

sr_one = df_seoul.loc['경기도']

# 그래프 그림 크기 지정
plt.figure(figsize=(14,5))

# x 축 눈금 반시계 90도 라벨 회전
plt.xticks(rotation='vertical')

# x,y 데이터를 그래프에 입력
plt.plot(sr_one.index, sr_one.values)

# 그래프 이름 설정
plt.title('서울 -> 경기도 인구 이동')

# 축 이름 지정
plt.xlabel('기간')
plt.ylabel('이동 인구수')

# 범례 표시
plt.legend(labels=['서울 -> 경기'], loc='best')

# 변경사항 저장 후 출력
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font', family='AppleGothic')    # 맥 한글 폰트 꺠짐 처리하기

df = pd.read_excel('../../data/part4/시도별 전출입 인구수.xlsx', header=0)

df = df.fillna(method='ffill')
mask = (df['전출지별'] == '서울특별시') & (df['전입지별'] != '서울특별시')          # 서울에서 서울이 아닌 다른 곳으로 이동한 데이터 추출
df_seoul = df[mask]                                                   
df_seoul = df_seoul.drop(['전출지별'], axis=1)                              # 전출지는 서울 이므로 삭제
df_seoul.rename({'전입지별':'전입지'}, axis=1, inplace=True)              # 전입지별 -> 전입지 로 변경
df_seoul.set_index('전입지', inplace=True)                                  # 전입지 열을 행 이름 인덱스로 변경

sr_one = df_seoul.loc['경기도']

# 스타일 서식 지정 (다른 파일을 실행해도 계속 적용된다)
plt.style.use('ggplot')

# 그림 사이즈 지정
plt.figure(figsize=(14,5))

## 주의사항! ##
# 그림 사이즈 설정과 스타일 서식 설정은 데이터 삽입 이전에 수행해야 한다 ##

# 데이터 삽입 및 마커 모양/크기 설정
plt.plot(sr_one.index, sr_one.values, marker='o', markersize=10)

# 타이틀 설정 및 축 이름 설정
plt.title('서울 투 경기')
plt.xlabel('기간')
plt.ylabel('이동 인구수')

# 축 이름 회전 및 폰트 사이즈 지정 (90도 반시계 && 10 사이즈)
plt.xticks(size=10, rotation=270)

# 범례 설정
plt.legend(labels=['서울 -> 경기'], loc='best', fontsize=15)

# y축 범위 지정
plt.ylim(50000, 800000)

# 주석 표시 - 화살표
plt.annotate('',
            xy=(20,620000),
            xytext=(2, 290000),
            xycoords='data',
            arrowprops=dict(arrowstyle='->', color='skyblue', lw=5))

plt.annotate('',
            xy=(47, 450000),
            xytext=(30, 580000),
            xycoords='data',
            arrowprops=dict(arrowstyle='->', color='olive', lw=5))

# 주석 표시 - 텍스트
plt.annotate('인구 이동 증가',
            xy=(10, 550000),
            va='baseline',
            rotation=25,
            ha='center',
            fontsize=15)

plt.annotate('인구 이동 감소',
            xy=(40, 560000),
            va='baseline',
            rotation=-11,
            ha='center',
            fontsize=15)

# 변경사항 저장 후 출력
plt.show()

# %%
# 가능한 plt 스타일 서식 확인하기
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %% [markdown]
# ### 1-2 화면 분할하여 그래프 여러개 그리기 - axe 객체 활용

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font', family='AppleGothic')    # 맥 한글 폰트 꺠짐 처리하기

df = pd.read_excel('../../data/part4/시도별 전출입 인구수.xlsx', header=0)

df = df.fillna(method='ffill')
mask = (df['전출지별'] == '서울특별시') & (df['전입지별'] != '서울특별시')          # 서울에서 서울이 아닌 다른 곳으로 이동한 데이터 추출
df_seoul = df[mask]                                                   
df_seoul = df_seoul.drop(['전출지별'], axis=1)                              # 전출지는 서울 이므로 삭제
df_seoul.rename({'전입지별':'전입지'}, axis=1, inplace=True)              # 전입지별 -> 전입지 로 변경
df_seoul.set_index('전입지', inplace=True)                                  # 전입지 열을 행 이름 인덱스로 변경

sr_one = df_seoul.loc['경기도']

# 그래프 객체 생성 (figure 에 2개의 서브 플롯 생성)
fig = plt.figure(figsize=(10,10))
ax1 = fig.add_subplot(2,1,1)    # 행의 개수, 열의 개수, 분할된 부분중 위치할 인덱스
ax2 = fig.add_subplot(2,1,2)    # 즉, 2행 1열의 분할 그래프상에서 위의 서브플롯은 첫번째, 밑의 서브플롯은 두번째를 의미한다.

# axe 객체에 plot 을 통해 그래프 출력
ax1.plot(sr_one, 'o', markersize=10)
ax2.plot(sr_one, marker='+', markerfacecolor='green', markersize=10, color='olive', linewidth=2, label='서울 -> 경기')
ax2.legend(loc='best')

# y축 범위 설정
ax1.set_ylim(50000,800000)
ax2.set_ylim(50000,800000)

# 축 눈금 라벨 설정 및 75도 회전
ax1.set_xticklabels(sr_one.index, rotation=75)
ax2.set_xticklabels(sr_one.index, rotation=75)


plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font', family='AppleGothic')    # 맥 한글 폰트 꺠짐 처리하기

df = pd.read_excel('../../data/part4/시도별 전출입 인구수.xlsx', header=0)

df = df.fillna(method='ffill')
mask = (df['전출지별'] == '서울특별시') & (df['전입지별'] != '서울특별시')          # 서울에서 서울이 아닌 다른 곳으로 이동한 데이터 추출
df_seoul = df[mask]                                                   
df_seoul = df_seoul.drop(['전출지별'], axis=1)                              # 전출지는 서울 이므로 삭제
df_seoul.rename({'전입지별':'전입지'}, axis=1, inplace=True)              # 전입지별 -> 전입지 로 변경
df_seoul.set_index('전입지', inplace=True)                                  # 전입지 열을 행 이름 인덱스로 변경

sr_one = df_seoul.loc['경기도']

fig = plt.figure(figsize=(20, 5))
ax = fig.add_subplot(1, 1, 1)

ax.plot(sr_one, marker='+', markerfacecolor='orange', markersize=10, color='olive', label='서울 -> 경기')
ax.legend(loc='best')

ax.set_ylim(50000, 800000)

ax.set_title('서울 -> 경기 인구 인동', size=20)

ax.set_xlabel('기간', size=12)
ax.set_ylabel('이동 인구수', size=12)

ax.set_xticklabels(sr_one.index, rotation=75)

ax.tick_params(axis='x', labelsize=10)
ax.tick_params(axis='y', labelsize=10)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font', family='AppleGothic')    # 맥 한글 폰트 꺠짐 처리하기

df = pd.read_excel('../../data/part4/시도별 전출입 인구수.xlsx', header=0)

df = df.fillna(method='ffill')
mask = (df['전출지별'] == '서울특별시') & (df['전입지별'] != '서울특별시')          # 서울에서 서울이 아닌 다른 곳으로 이동한 데이터 추출
df_seoul = df[mask]                                                   
df_seoul = df_seoul.drop(['전출지별'], axis=1)                              # 전출지는 서울 이므로 삭제
df_seoul.rename({'전입지별':'전입지'}, axis=1, inplace=True)                # 전입지별 -> 전입지 로 변경
df_seoul.set_index('전입지', inplace=True)                                  # 전입지 열을 행 이름 인덱스로 변경

sr_one = df_seoul.loc['경기도']

# 행은 지역 3개 선택, 열은 1970 년대 부터 2018 선택
col_years = list(map(str, range(1970, 2018)))
ndf = df_seoul.loc[['충청남도', '경상북도', '강원도'], col_years]

# 스타일 서식 지정
plt.style.use('ggplot')

# 그래프 객체 생성
fig = plt.figure(figsize=(20,5))
ax = fig.add_subplot(1,1,1)

# axe 객체에 plot 함수를 통해 그래프 출력
ax.plot(col_years, ndf.loc['충청남도', :], marker='o', markerfacecolor='green', markersize=5, color='olive', label='서울 -> 충청남도')
ax.plot(col_years, ndf.loc['경상북도', :], marker='o', markerfacecolor='blue', markersize=5, color='skyblue', label='서울 -> 경상북도')
ax.plot(col_years, ndf.loc['강원도', :], marker='o', markerfacecolor='red', markersize=5, color='magenta', label='서울 -> 강원도')

# 범례 표시
ax.legend(loc='best')

# 차트 제목 추가
ax.set_title('서울 -> 충남, 경북, 강원 이동 인구', size=20)

# 축 이름 추가
ax.set_xlabel('기간', size=12)
ax.set_ylabel('이동 인구수', size=12)

# 축 눈금 라벨 지정 및 90도 회전
ax.set_xticklabels(col_years, rotation=90)

# 축 눈금 라벨 크기
ax.tick_params(axis='x', labelsize=10)
ax.tick_params(axis='y', labelsize=10)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font', family='AppleGothic')    # 맥 한글 폰트 꺠짐 처리하기

df = pd.read_excel('../../data/part4/시도별 전출입 인구수.xlsx', header=0)

df = df.fillna(method='ffill')
mask = (df['전출지별'] == '서울특별시') & (df['전입지별'] != '서울특별시')          # 서울에서 서울이 아닌 다른 곳으로 이동한 데이터 추출
df_seoul = df[mask]                                                   
df_seoul = df_seoul.drop(['전출지별'], axis=1)                              # 전출지는 서울 이므로 삭제
df_seoul.rename({'전입지별':'전입지'}, axis=1, inplace=True)                # 전입지별 -> 전입지 로 변경
df_seoul.set_index('전입지', inplace=True)                                  # 전입지 열을 행 이름 인덱스로 변경

####################################################################################################################

# 필요 데이터 추출
col_years = list(map(str, range(1970, 2018)))
ndf = df_seoul.loc[['충청남도', '강원도', '경기도', '경상남도'], col_years]

# 스타일 서식 지정
plt.style.use('ggplot')

# 그래프 객체 생성
fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)

# axe 객체에 그래프 값 삽입 및 그리기
ax1.plot(col_years, ndf.loc['충청남도', :], marker='o', markerfacecolor='green', color='olive', label='서울 -> 충남')
ax2.plot(col_years, ndf.loc['강원도', :], marker='o', markerfacecolor='blue', color='skyblue', label='서울 -> 강원')
ax3.plot(col_years, ndf.loc['경기도', :], marker='o', markerfacecolor='red', color='magenta', label='서울 -> 경기')
ax4.plot(col_years, ndf.loc['경상남도', :], marker='o', markerfacecolor='yellow', color='orange', label='서울 -> 경남')

# 범례 표시
ax1.legend(loc='best')
ax2.legend(loc='best')
ax3.legend(loc='best')
ax4.legend(loc='best')

# 차트 제목 추가
ax1.set_title('서울 -> 충남 인구 이동', size=12)
ax2.set_title('서울 -> 강원 인구 이동', size=12)
ax3.set_title('서울 -> 경기 인구 이동', size=12)
ax4.set_title('서울 -> 경남 인구 이동', size=12)

# 축 눈금 라벨 지정 및 90도 회전
ax1.set_xticklabels(col_years, rotation=90)
ax2.set_xticklabels(col_years, rotation=90)
ax3.set_xticklabels(col_years, rotation=90)
ax4.set_xticklabels(col_years, rotation=90)

plt.show()

# %%
# matplotlib 에서 사용가능한 색깔 정보 확인하기
import matplotlib

colors = {}

for name, hex in matplotlib.colors.cnames.items():
    colors[name] = hex

# colors

# %% [markdown]
# ### (1-3) 면적 그래프

# %%
from pandas import pandas as pd
from matplotlib import pyplot as plt
from matplotlib import rc

rc('font', family='AppleGothic')    # 맥 한글 폰트 꺠짐 처리하기

df = pd.read_excel('../../data/part4/시도별 전출입 인구수.xlsx', header=0)

df.fillna(method='ffill', inplace=True)
mask = (df['전출지별'] == '서울특별시') & (df['전입지별'] != '서울특별시')          # 서울에서 서울이 아닌 다른 곳으로 이동한 데이터 추출
df_seoul = df[mask]                                                   
df_seoul = df_seoul.drop(['전출지별'], axis=1)                              # 전출지는 서울 이므로 삭제
df_seoul.rename({'전입지별':'전입지'}, axis=1, inplace=True)                # 전입지별 -> 전입지 로 변경
df_seoul.set_index('전입지', inplace=True)     

#########################################################################################################################

col_years = list(map(str, range(1970, 2018)))
ndf = df_seoul.loc[['충청남도', '경상북도', '강원도', '전라남도'], col_years]
ndf = ndf.transpose()

plt.style.use('ggplot')

ndf.index = ndf.index.map(int)

ndf.plot(kind='area', stacked=False, alpha=0.2, figsize=(20,10))

plt.title('서울 -> 타시도 인구 이동', size=10)
plt.ylabel('이동 인구 수', size=20)
plt.xlabel('기간', size=20)
plt.legend(loc='best', fontsize=15)

plt.show()
